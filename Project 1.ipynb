# %% [markdown]
# This notebook will be mainly used for the capstone project

# %%
Import pandas as pd
Import numpy as np
# Out:
#   File "<ipython-input-1-96c2d2b38c3e>", line 1
#     Import pandas as pd
#                 ^
# SyntaxError: invalid syntax
